# %%
training_set.head()
# Out:
#    object_id         mjd  passband        flux   flux_err  detected
# 0        615  59750.4229         2 -544.810303   3.622952         1
# 1        615  59750.4306         1 -816.434326   5.553370         1
# 2        615  59750.4383         3 -471.385529   3.801213         1
# 3        615  59750.4450         4 -388.984985  11.395031         1
# 4        615  59752.4070         2 -681.858887   4.041204         1

# %%
training_set_metadata.head()
# Out:
#    object_id          ra       decl       gal_l      gal_b  ddf  \
# 0        615  349.046051 -61.943836  320.796530 -51.753706    1
# 1        713   53.085938 -27.784405  223.525509 -54.460748    1
# 2        730   33.574219  -6.579593  170.455585 -61.548219    1
# 3        745    0.189873 -45.586655  328.254458 -68.969298    1
# 4       1124  352.711273 -63.823658  316.922299 -51.059403    1
#
#    hostgal_specz  hostgal_photoz  hostgal_photoz_err  distmod  mwebv  target
# 0         0.0000          0.0000              0.0000      NaN  0.017      92
# 1         1.8181          1.6267              0.2552  45.4063  0.007      88
# 2         0.2320          0.2262              0.0157  40.2561  0.021      42
# 3         0.3037          0.2813              1.1523  40.7951  0.007      90
# 4         0.1934          0.2415              0.0176  40.4166  0.024      90

# %%
for obj_id in class90[:30]:
    df = training_set[training_set.object_id==obj_id]
    df.head()
    min_date = df.mjd.astype(int).min()
    max_date = df.mjd.astype(int).max()
    print('class:', training_set_metadata[training_set_metadata.object_id==obj_id].target.values)
    print('distmod:', training_set_metadata[training_set_metadata.object_id==obj_id].distmod.values)
    plt.figure(figsize=(20,5))
    for channel in range(6):
        mask = df.passband==channel
        plt.scatter(df[mask].mjd, df[mask].flux,)
    for i in range(3):
        plt.axvline(min_date+i*365)
    plt.show()
# Out:
# class: [90]
# distmod: [40.7951]
# class: [90]
# distmod: [40.4166]
# class: [90]
# distmod: [39.7279]
# class: [90]
# distmod: [41.1401]
# class: [90]
# distmod: [39.8317]
# class: [90]
# distmod: [42.6207]
# class: [90]
# distmod: [40.1939]
# class: [90]
# distmod: [42.737]
# class: [90]
# distmod: [40.8445]
# class: [90]
# distmod: [40.6793]
# class: [90]
# distmod: [41.6735]
# class: [90]
# distmod: [42.5888]
# class: [90]
# distmod: [41.8371]
# class: [90]
# distmod: [39.8011]
# class: [90]
# distmod: [42.1592]
# class: [90]
# distmod: [42.7983]
# class: [90]
# distmod: [38.5591]
# class: [90]
# distmod: [43.0404]
# class: [90]
# distmod: [40.2248]
# class: [90]
# distmod: [42.3102]
# class: [90]
# distmod: [42.0472]
# class: [90]
# distmod: [46.4913]
# class: [90]
# distmod: [42.5685]
# class: [90]
# distmod: [41.3068]
# class: [90]
# distmod: [41.0501]
# class: [90]
# distmod: [41.5643]
# class: [90]
# distmod: [40.631]
# class: [90]
# distmod: [41.4527]
# class: [90]
# ...
